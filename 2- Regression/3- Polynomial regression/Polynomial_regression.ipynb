# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv("Position_Salaries.csv")
X = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %%
print(y.shape)
# Out:
# (10,)

# %%
print(X.shape)
# Out:
# (10, 1)

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X,y)
y_lin = lin_reg.predict(X)

# %%
print(y_lin)
# Out:
# [-114454.54545455  -33575.75757576   47303.03030303  128181.81818182
#   209060.60606061  289939.39393939  370818.18181818  451696.96969697
#   532575.75757576  613454.54545455]

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)

# %%
print(X_poly)
# Out:
# [[1.000e+00 1.000e+00 1.000e+00 1.000e+00 1.000e+00]
#  [1.000e+00 2.000e+00 4.000e+00 8.000e+00 1.600e+01]
#  [1.000e+00 3.000e+00 9.000e+00 2.700e+01 8.100e+01]
#  [1.000e+00 4.000e+00 1.600e+01 6.400e+01 2.560e+02]
#  [1.000e+00 5.000e+00 2.500e+01 1.250e+02 6.250e+02]
#  [1.000e+00 6.000e+00 3.600e+01 2.160e+02 1.296e+03]
#  [1.000e+00 7.000e+00 4.900e+01 3.430e+02 2.401e+03]
#  [1.000e+00 8.000e+00 6.400e+01 5.120e+02 4.096e+03]
#  [1.000e+00 9.000e+00 8.100e+01 7.290e+02 6.561e+03]
#  [1.000e+00 1.000e+01 1.000e+02 1.000e+03 1.000e+04]]

# %%
from sklearn.linear_model import LinearRegression
lin_reg2 = LinearRegression()
lin_reg2.fit(X_poly,y)
y_poly = lin_reg2.predict(X_poly)

# %%
print(y_poly)
# Out:
# [ 53356.64335675  31759.90675984  58642.1911421   94632.86713282
#  121724.94172495 143275.05827509 184003.49650352 289994.17249417
#  528694.63869462 988916.08391613]

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X,y,label ='Data')
plt.plot(X,y_lin, label ='Linear Regression',color = "y")
plt.xlabel("Years of Expierence")
plt.ylabel("Salaries")
plt.legend()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X,y,label ='Data')
plt.plot(X,y_poly, label ='Polynomial Regression',color = "g")
plt.xlabel("Position Level")
plt.ylabel("Salaries")
plt.legend()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, lin_reg2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
#lin_reg2.predict([[1,6.5,42.25,274.625,1785.0625]]) 
#[[]] double square for input as 2d array in predict method
lin_reg2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265155])

# %%
6.5**4
# Out:
# 1785.0625
